# %% [markdown]
# # **퇴사**
#
# 상담원인 백준이는 오늘부터 N+1일 째 되는 날 퇴사를 하기 위해, 남은 N일 동안 최대한 많은 상담을 하려고 한다.
#
# 비서는 하루에 하나씩 서로 다른 사람의 상담을 잡아 놓았다.
#
# 각각의 상담은 상담을 완료하는데 걸리는 기간 Ti와 상담을 했을 때 받을 수 있는 금애 Pi로 이루어져 있다.
#
# 상담이 완료되지 못하거나, N+1일 이후에는 상담을 할 수 없다.
#
# 상담을 적절히 했을 때, 얻을 수 있는 최대 수익을 구하는 프로그램 작성

# %%
n = int(input())

count = []
for _ in range(n):
    count.append(list(map(int, input().split())))


result = 0
for i in range(0, n):
    day = i
    pay = 0
    while True:
        if day >= n:
            break
        else:
            if day + count[day][0] > n:
                break

            else:
                pay += count[day][1]
                day += count[day][0]

    result = max(result, pay)

print(result)
# Out:
# 10
# 5 50
# 4 40
# 3 30
# 2 20
# 1 10
# 1 10
# 2 20
# 3 30
# 4 40
# 5 50
# 80

# %%
n = int(input())        # 전체 상담 개수
t = []                  # 각 상담을 완료하는데 걸리는 시간
p = []                  # 각 상담을 완료했을 때 받는 금액
dp = [0] * (n+1)        # 다이나믹 프로그래밍을 위한 1차원 dp 테이블
max_value = 0

for _ in range(n):
    x, y = map(int, input().split())
    t.append(x)
    p.append(y)


# 리스트를 뒤에서부터 거꾸로 확인
for i in range(n-1, -1, -1):
    time = t[i] + i

    # 상담이 기간 안에 끝나는 경우
    if time <= n:
        # 점화식에 맞게 계산
        dp[i] = max(p[i] + dp[time], max_value)
        max_value = dp[i]

    # 상담이 기간을 벗어나는 경우
    else:
        dp[i] = max_value

print(max_value)
