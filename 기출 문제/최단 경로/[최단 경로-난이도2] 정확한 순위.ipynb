# %% [markdown]
# # **정확한 순위**
#
# 선생님은 시험을 본 학생 N명의 성적을 분실하고, 성적을 비교한 결과의 일부만 가지고 있다.
#
# 학생 N명의 성적은 모두 다른데, 예를들어, 다음은 6명의 학생에 대하여 6번만 성적을 비교한 결과이다.
# - 1번 학생 성적 < 5번 학생 성적
# - 3번 학생 성적 < 4번 학생 성적
# - 4번 학생 성적 < 2번 학생 성적
# - 4번 학생 성적 < 6번 학생 성적
# - 5번 학생 성적 < 2번 학생 성적
# - 5번 학생 성적 < 4번 학생 성적
#
# A번 학생의 성적이 B번 학생의 성적보다 낮다면 화살표가 A에서 B를 가리키도록 한다.
#
# 학생의 성적은 정확히 알 수 도 있고, 알 수도 없다. (4번 학생만 알 수 있다.)
#
# 학생들의 성적을 비교한 결과가 주어질 때, 성적 순위를 정확히 알 수 있는 학생은 모두 몇 명인지 계산하시오.

# %%
INF = int(1e9)

n, m = map(int, input().split())
graph = [[INF] * (n+1) for _ in range(n+1)]

for a in range(1, n+1):
    for b in range(1, n+1):
        if a == b:
            graph[a][b] = 0

for _ in range(m):
    a, b = map(int, input().split())
    graph[a][b] = 1


for k in range(1, n+1):
    for a in range(1, n+1):
        for b in range(1, n+1):
            graph[a][b] = min(graph[a][b], graph[a][k] + graph[k][b])


result = 0
# 각 학생을 번호에 따라 한 명씩 확인하며 도달 가능한지 체크
for i in range(1, n+1):
    count = 0
    for j in range(1, n+1):
        if graph[i][j] != INF or graph[j][i] != INF:
            count += 1
    if count == n:
        result += 1

print(result)
# Out:
# 6 6
# 1 5
# 3 4
# 4 2
# 4 6
# 5 2
# 5 4
# 1
